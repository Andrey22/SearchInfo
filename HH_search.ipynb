# %%
from lxml import html
import requests

# %%
hh_request = requests.get('https://hh.ru/search/vacancy?text=python&area=1&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=&items_on_page=20&no_magic=true')
print(hh_request.text)
# Out:
# <html>
# <head><title>404 Not Found</title></head>
# <body>
# <center><h1>404 Not Found</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %%
hh = requests.get('https://hh.ru')
hh = hh.text
html.

# %%
requests.get('https://google.com')
# Out:
# <Response [200]>

# %%
hh = requests.get('https://hh.ru/search/vacancy', params={'value': 'python'})
hh.text
# Out:
# '<html>\r\n<head><title>404 Not Found</title></head>\r\n<body>\r\n<center><h1>404 Not Found</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
hh = requests.get('https://hh.ru/search/resume?text=python&area=17&clusters=true&exp_period=all_time&logic=normal&pos=full_text')
hh.text
# Out:
# '<html>\r\n<head><title>404 Not Found</title></head>\r\n<body>\r\n<center><h1>404 Not Found</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
import requests
from lxml import html
import pprint
hh_headers = {'accept': '*/*', 
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
hh_url = 'https://hh.ru/search/vacancy?area=1&text=python'

def get_search_hh(headers, url):
    hh_sessions = requests.Session()
    request = hh_sessions.get(url, headers=headers)
    return_html = html.fromstring(request.text)
    return return_html

def get_jobs(headers, url):
    root = get_search_hh(headers, url)
    count_int = 1
    count_pages = 2
    result_hh = []
    result_p
    while True:
        count_jobs = str(count_int)
        
        result_hh_salary = root.xpath("/html[1]/body[1]/div[5]/div[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]/div["+ count_jobs +"]/div[1]/div[2]/div[1]/text()")
        result_hh_name = root.xpath("//div[@class='vacancy-serp']//div["+ count_jobs +"]//div[1]//div[1]//div[1]//a[1]/text()")
        count_int += 1
        empty_7, empty_8, empty_15, empty_16 = '7', '8', '15', '16' 
        if count_jobs == empty_7:
            continue
        if count_jobs == empty_8:
            continue
        if count_jobs == empty_15:
            continue
        if count_jobs == empty_16:
            continue
        result_hh_link = root.xpath("//div[@class='vacancy-serp']//div[2]//div[1]//div[1]//div[1]//a[1]/@href")
        if result_hh_salary == []:
            result_hh_salary = 'Не указанна'
        if count_int == 26:
            break

        result_hh_name = (str(result_hh_name))
        
        result_hh.append(f'Вакансия ' + result_hh_name + ' - Зарплата ' + str(result_hh_salary) + ' - Link ' + str(result_hh_link))
        #result_hh.append(f'Вакансия ' + result_hh_name + ' - Зарплата ' + str(result_hh_salary))
    
    return result_hh
    
def record_to_file(files):
    with open("file22.txt", "w") as file:
        for i in files:
            file.write(str(i)+ '\n')
    
    
get_jobs(hh_headers, hh_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-f63dc81859d3> in <module>
#      52
#      53
# ---> 54 get_jobs(hh_headers, hh_url)
#
# <ipython-input-94-f63dc81859d3> in get_jobs(headers, url)
#      17     count_pages = 2
#      18     result_hh = []
# ---> 19     result_p
#      20     while True:
#      21         count_jobs = str(count_int)
#
# NameError: name 'result_p' is not defined

# %%
## Copy 2

import requests
from lxml import html
import pprint
import re

hh_headers = {'accept': '*/*', 
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
hh_url = 'https://hh.ru/search/vacancy?area=1&text=python'

def get_search_hh(headers, url):
    hh_sessions = requests.Session()
    request = hh_sessions.get(url, headers=headers)
    return_html = html.fromstring(request.text)
    return return_html

def get_jobs(headers, url):
    root = get_search_hh(headers, url)
    count_int = 1
    result_hh = []
    re_name = r'[а-яА-Яa-zA-Z\(\)\,]'
    while True:
        count_jobs = str(count_int)
        result_hh_salary = root.xpath("/html[1]/body[1]/div[5]/div[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]/div["+ count_jobs +"]/div[1]/div[2]/div[1]/text()")
        result_hh_name = root.xpath("//div[@class='vacancy-serp']//div["+ count_jobs +"]//div[1]//div[1]//div[1]//a[1]/text()")
        count_int += 1
        empty_7, empty_8, empty_15, empty_16 = '7', '8', '15', '16' 
        if count_jobs == empty_7:
            continue
        if count_jobs == empty_8:
            continue
        if count_jobs == empty_15:
            continue
        if count_jobs == empty_16:
            continue
        result_hh_link = root.xpath("//div[@class='vacancy-serp']//div[2]//div[1]//div[1]//div[1]//a[1]/@href")
        
        

        
        if result_hh_salary == []:
            result_hh_salary = 'Не указанна'
        if count_int == 26:
            break
        
        result_hh_name = (str(result_hh_name))
        

        result_hh.append(f'Вакансия ' + result_hh_name + ' - Зарплата ' + str(result_hh_salary) + ' - Link ' + str(result_hh_link))
        #result_hh.append(f'dfd {result_hh_name}')
        
    return (result_hh)

def clear_hh(cc):
    cc = cc.text
    re_name = r'[а-яА-Яa-zA-Z\(\)\,]'
    rr = re.search(re_name, cc)
    return rr

def record_to_file(files):
    with open("file22.txt", "w") as file:
        for i in files:
            file.write(str(i)+ '\n')
    
    
get_jobs(hh_headers, hh_url)
# Out:
# ["Вакансия ['Разработчик Python'] - Зарплата Не указанна - Link ['https://hh.ru/vacancy/32158934?query=python']",
#  "Вакансия ['Python/Django разработчик'] - Зарплата ['60\\xa0000-100\\xa0000 руб.'] - Link ['https://hh.ru/vacancy/32158934?query=python']",
#  "Вакансия ['Backend Developer (Python, Django)'] - Зарплата ['160\\xa0000-200\\xa0000 руб.'] - Link ['https://hh.ru/vacancy/32158934?query=python']",
#  "Вакансия ['Python Data Scientist'] - Зарплата ['от 150\\xa0000 руб.'] - Link ['https://hh.ru/vacancy/32158934?query=python']",
#  "Вакансия ['Разработчик Python'] - Зарплата Не указанна - Link ['https://hh.ru/vacancy/32158934?query=python']",
#  "Вакансия ['Senior python developer в Трипстер (Python, Django, Celery, Redis, Elasticsearch)'] - Зарплата ['до 200\\xa0000 руб.'] - Link ['https://hh.ru/vacancy/32158934?query=python']",
#  "Вакансия ['Python-разработчик'] - Зарплата ['до 200\\xa0000 руб.'] - Link ['https://hh.ru/vacancy/32158934?query=python']",
# ...

# %%
txt = '[banana]'
ttt = ['Python/Django разработчик']
x = txt.lstrip('[' + '[')
x = txt.rstrip('[' + '[')

print("of all fruits", x, "is my favorite")
print("of all fruits, {} , is my favorite".format(ttt.extend()))
# Out:
# of all fruits [banana] is my favorite
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-bc79065c59d1> in <module>
#       5
#       6 print("of all fruits", x, "is my favorite")
# ----> 7 print("of all fruits, {} , is my favorite".format(ttt.extend()))
#
# TypeError: extend() takes exactly one argument (0 given)

# %%
txt = "banana,,,,,[ssaaww....."

x = txt.rstrip(",.[asw")

print(x)
# Out:
# banana,,,,,[ssaaww]

# %%
## Copy 2

import requests
from lxml import html
import pprint
import re

#hh_headers = {'accept': '*/*', 
              #'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
vacancy_input = input('Please enter the name of the vacancy: ')
#hh_url = f'https://hh.ru/search/vacancy?area=1&text={vacancy_input}'

def get_search_hh(headers, url):
    hh_sessions = requests.Session()
    request = hh_sessions.get(url, headers=headers)
    return_html = html.fromstring(request.text)
    return return_html

def clear_texts(text):
    text = str(text)
    text2 = text.replace("]", '')
    text3 = text2.replace("'","")
    text4 = text3.replace("[", '')
    text5 = text4.replace("]", '')
    text6 = text5.replace("\\", '')
    text7 = text6.replace("xa0", ' ')
    return text7

def record_to_file(files, name_file):
    with open(f"{name_file}.csv", "w") as file:
        for i in files:
            file.write(str(i) + '\n')


def get_jobs(url):
    root = url
    count_int = 1
    result_hh = []
    while True:
        count_jobs = str(count_int)
        result_hh_salary = root.xpath("/html[1]/body[1]/div[5]/div[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]/div["+ count_jobs +"]/div[1]/div[2]/div[1]/text()")
        if result_hh_salary == []:
            result_hh_salary = 'Не указанна'
        result_hh_salary = clear_texts(result_hh_salary)
        result_hh_name = root.xpath("//div[@class='vacancy-serp']//div["+ count_jobs +"]//div[1]//div[1]//div[1]//a[1]/text()")
        result_hh_name = clear_texts(result_hh_name)
        count_int += 1
        empty_7, empty_8, empty_15, empty_16 = '7', '8', '15', '16' 
        if count_jobs == empty_7:
            continue
        if count_jobs == empty_8:
            continue
        if count_jobs == empty_15:
            continue
        if count_jobs == empty_16:
            continue
        result_hh_link = root.xpath("//div[@class='vacancy-serp']//div[2]//div[1]//div[1]//div[1]//a[1]/@href")
        result_hh_link = clear_texts(result_hh_link)
        if count_int == 26:
            break
        result_hh_name = (str(result_hh_name))
        result_hh.append(f'Вакансия ' + result_hh_name + ' - Зарплата ' + str(result_hh_salary) + ' - Link ' + str(result_hh_link) + '\\n')    
    return result_hh

def get_all_vacancy(vacancy):
    hh_headers = {'accept': '*/*', 
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
    count_pages = 0
    all_pages = []
    while True:
        hh_url = (f"https://hh.ru/search/vacancy?area=1&text={vacancy}&page={count_pages}")
        count_pages += 1
        hh_one_root_page = get_search_hh(hh_headers, hh_url)
        jobs_one_page = get_jobs(hh_one_root_page)
        ##проверка наличии страницы и выход из цикла
        check_sessions = requests.Session()
        request_hh = check_sessions.get(hh_url, headers=hh_headers)
        if request_hh.status_code == 404:
            break
        ##########
        all_pages.append(jobs_one_page)
    return all_pages

get_all_vacancy(vacancy_input) 
#get_jobs(hh_headers, hh_url)
# Out:
# Please enter the name of the vacancy: python
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-244-e1d1a21900c5> in <module>
#      82     return all_pages
#      83
# ---> 84 get_all_vacancy(vacancy_input)
#      85 #get_jobs(hh_headers, hh_url)
#
# ...

# %%
vacancy_input = input('Please enter name of vacancy: ')
hh_url = f'https://hh.ru/search/vacancy?area=1&text={vacancy_input}'
print(hh_url)
# Out:
# Please enter name of vacancy: python
# https://hh.ru/search/vacancy?area=1&text=python

# %%
url_test = 'https://hh.ru/search/vacancy?area=1&text=python&page=100'
hh_headers = {'accept': '*/*', 
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
check_sessions = requests.Session()
request_hh = check_sessions.get(url_test, headers=hh_headers)
if request_hh.status_code == 404:
    print('No')
# Out:
# No

# %%
## Copy 2

import requests
from lxml import html
import pprint
import re

vacancy_input = input('Please enter the name of the vacancy: ')
number_of_pages = int(input('Please enter the count of pages: '))

def get_search_hh(headers, url):
    hh_sessions = requests.Session()
    request = hh_sessions.get(url, headers=headers)
    return_html = html.fromstring(request.text)
    return return_html

def clear_texts(text): #функция для очистки от не лишних символов
    text = str(text)
    text2 = text.replace("]", '')
    text3 = text2.replace("'","")
    text4 = text3.replace("[", '')
    text5 = text4.replace("]", '')
    text6 = text5.replace("\\", '')
    text7 = text6.replace("xa0", ' ')
    return text7

def record_to_file(files, name_file): # функция для записи в файл с именем введенный в number_of_pages
    with open(f"{name_file}.txt", "w") as file:
        for i in files:
            file.writelines(str(i) + '\n')

def get_jobs(root): # функция для парсинга одной станицы
    count_int = 1
    result_hh = []
    while True:
        count_jobs = str(count_int)
        result_hh_salary = root.xpath("/html[1]/body[1]/div[5]/div[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]/div["+ count_jobs +"]/div[1]/div[2]/div[1]/text()")
        if result_hh_salary == []:
            result_hh_salary = 'Не указанна'
        result_hh_salary = clear_texts(result_hh_salary)
        result_hh_name = root.xpath("//div[@class='vacancy-serp']//div["+ count_jobs +"]//div[1]//div[1]//div[1]//a[1]/text()")
        result_hh_name = clear_texts(result_hh_name)
        count_int += 1
        empty_7, empty_8, empty_15, empty_16 = '7', '8', '15', '16' 
        if count_jobs == empty_7:
            continue
        if count_jobs == empty_8:
            continue
        if count_jobs == empty_15:
            continue
        if count_jobs == empty_16:
            continue
        result_hh_link = root.xpath("//div[@class='vacancy-serp']//div[2]//div[1]//div[1]//div[1]//a[1]/@href")
        result_hh_link = clear_texts(result_hh_link)
        if count_int == 26:
            break
        hh_row = result_hh.append(f'Вакансия {str(result_hh_name)} - Зарплата {str(result_hh_salary)} - Link {str(result_hh_link)}')
        
        hh_row = str(hh_row)
        result_hh.append(hh_row)
        result_hh += hh_row
    return result_hh

def get_all_vacancy(vacancy, page_numbers): # функция для парсинга более одной страницы. vacancy - необходимо ввести название вакансии, page_numbers - ввести кол-во страниц для парсинга
    hh_headers = {'accept': '*/*', 
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
    count_pages = 0
    all_pages = []
    while True:
        hh_url = (f"https://hh.ru/search/vacancy?area=1&text={vacancy}&page={count_pages}")
        
        hh_one_root_page = get_search_hh(hh_headers, hh_url)
        jobs_one_page = get_jobs(hh_one_root_page)
        if count_pages == page_numbers:
            break
        count_pages += 1
        all_pages.append(jobs_one_page)
    return all_pages

get_all_vacancy(vacancy_input, number_of_pages)
# Out:
# Please enter the name of the vacancy: python
# Please enter the count of pages: 2
# [['Вакансия Разработчик Python - Зарплата 160 000-200 000 руб. - Link https://hh.ru/vacancy/32470111?query=python',
#   'None',
#   'N',
#   'o',
#   'n',
#   'e',
#   'Вакансия Python developer (Cloud Services) - Зарплата 150 000-230 000 руб. - Link https://hh.ru/vacancy/32470111?query=python',
#   'None',
#   'N',
#   'o',
#   'n',
#   'e',
#   'Вакансия Python разработчик - Зарплата Не указанна - Link https://hh.ru/vacancy/32470111?query=python',
#   'None',
#   'N',
#   'o',
#   'n',
#   'e',
#   'Вакансия Python Developer - Зарплата Не указанна - Link https://hh.ru/vacancy/32470111?query=python',
#   'None',
#   'N',
#   'o',
#   'n',
#   'e',
#   'Вакансия Разработчик Python - Зарплата Не указанна - Link https://hh.ru/vacancy/32470111?query=python',
#   'None',
#   'N',
#   'o',
#   'n',
#   'e',
# ...

# %%
## Copy 3

import requests
from lxml import html
import pprint
import re

vacancy_input = input('Please enter the name of the vacancy: ')
number_of_pages = int(input('Please enter the count of pages: '))

def get_search_hh(headers, url):
    hh_sessions = requests.Session()
    request = hh_sessions.get(url, headers=headers)
    return_html = html.fromstring(request.text)
    return return_html

def clear_texts(text): #функция для очистки от не лишних символов
    text = str(text)
    text2 = text.replace("]", '')
    text3 = text2.replace("'","")
    text4 = text3.replace("[", '')
    text5 = text4.replace("]", '')
    text6 = text5.replace("\\", '')
    text7 = text6.replace("xa0", ' ')
    return text7

def record_to_file(files, name_file): # функция для записи в файл с именем введенный в number_of_pages
    with open(f"{name_file}.txt", "w") as file:
        for i in files:
            file.write(str(i) + '\n')



def get_all_vacancy(vacancy, page_numbers): # функция для парсинга более одной страницы. vacancy - необходимо ввести название вакансии, page_numbers - ввести кол-во страниц для парсинга
    hh_headers = {'accept': '*/*', 
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
    count_pages = 0
    all_pages = []
    result_hh = []
    while True:
        hh_url = (f"https://hh.ru/search/vacancy?area=1&text={vacancy}&page={count_pages}")
        root = get_search_hh(hh_headers, hh_url)
        while True:
            
            

            count_int = 1
            
            hh_row = ''

            while True:
                count_jobs = str(count_int)
                result_hh_salary = root.xpath("/html[1]/body[1]/div[5]/div[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]/div["+ count_jobs +"]/div[1]/div[2]/div[1]/text()")
                if result_hh_salary == []:
                    result_hh_salary = 'Не указанна'
                result_hh_salary = clear_texts(result_hh_salary)
                result_hh_name = root.xpath("//div[@class='vacancy-serp']//div["+ count_jobs +"]//div[1]//div[1]//div[1]//a[1]/text()")
                result_hh_name = clear_texts(result_hh_name)
                
                empty_7, empty_8, empty_15, empty_16 = '7', '8', '15', '16' 
                if count_jobs == empty_7:
                    continue
                if count_jobs == empty_8:
                    continue
                if count_jobs == empty_15:
                    continue
                if count_jobs == empty_16:
                    continue
                result_hh_link = root.xpath("//div[@class='vacancy-serp']//div[2]//div[1]//div[1]//div[1]//a[1]/@href")
                result_hh_link = clear_texts(result_hh_link)
                
                hh_row = (f'Вакансия {str(result_hh_name)} - Зарплата {str(result_hh_salary)} - Link {str(result_hh_link)}')
                result_hh.append(hh_row)

                if count_int == 26:
                    break
                count_int += 1
        

            if count_pages == page_numbers:
                break
            count_pages += 1
            all_pages.append(result_hh)
    return all_pages

get_all_vacancy(vacancy_input, number_of_pages)
# Out:
# Please enter the name of the vacancy: python
# Please enter the count of pages: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-379-8cb04d5a8bde> in <module>
#      84     return all_pages
#      85
# ---> 86 get_all_vacancy(vacancy_input, number_of_pages)
#
# <ipython-input-379-8cb04d5a8bde> in get_all_vacancy(vacancy, page_numbers)
#      55                     result_hh_salary = 'Не указанна'
#      56                 result_hh_salary = clear_texts(result_hh_salary)
# ---> 57                 result_hh_name = root.xpath("//div[@class='vacancy-serp']//div["+ count_jobs +"]//div[1]//div[1]//div[1]//a[1]/text()")
#      58                 result_hh_name = clear_texts(result_hh_name)
#      59
#
# KeyboardInterrupt:

# %%
import math

# %%
math.
