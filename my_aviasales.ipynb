# %%
import re
import requests
import pprint
import json
import urllib
import urllib3

# %%
#city_request = requests.get('http://api.travelpayouts.com/data/ru/cities.json')
#airport_request = requests.get('http://api.travelpayouts.com/data/ru/airports.json')



#city_text = city_request.text
#airport_text = airport_request.text

#city_json = json.loads(city_text)
#airport_json = json.loads(airport_text)

#data_serialized = json.dumps(city_json)
#data_serialized = json.dump(airport_json, open('data_avia2.json', 'w'))
#pprint.pprint(data_serialized)

# %%
print(type(city_text))
# Out:
# <class 'str'>

# %%
json_file = open('cities.json','r')
city_json = json.load(json_file)
json_file.close()
pprint.pprint(city_json)
# Out:
# [{'cases': {'da': '', 'pr': '', 'ro': '', 'tv': '', 'vi': ''},
#   'code': 'ZSH',
#   'coordinates': {'lat': 30.236935, 'lon': 120.43236},
#   'country_code': 'US',
#   'name': 'Санта-Фе',
#   'name_translations': {'en': 'Santa Fe'},
#   'time_zone': 'America/Denver'},
#  {'cases': {'da': 'Аль-Ариш',
#             'pr': 'Аль-Ариш',
#             'ro': 'Аль-Ариш',
#             'tv': 'Аль-Ариш',
#             'vi': 'в Аль-Ариш'},
#   'code': 'AAC',
#   'coordinates': {'lat': 31.133333, 'lon': 33.75},
#   'country_code': 'EG',
#   'name': 'Эль-Ариш',
#   'name_translations': {'en': 'El Arish'},
#   'time_zone': 'Africa/Cairo'},
#  {'cases': {'da': '', 'pr': '', 'ro': '', 'tv': '', 'vi': ''},
#   'code': 'UKT',
#   'coordinates': {'lat': 40.433334, 'lon': -75.35},
#   'country_code': 'US',
#   'name': 'Квакертаун',
#   'name_translations': {'en': 'Quakertown'},
#   'time_zone': 'America/New_York'},
#  {'cases': {'da': '', 'pr': '', 'ro': '', 'tv': '', 'vi': ''},
#   'code': 'ORP',
# ...

# %%
type(city_json)
# Out:
# list

# %%
city

# %%
city_text
